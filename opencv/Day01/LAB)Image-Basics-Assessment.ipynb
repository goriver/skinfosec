# %% [markdown]
# # Image Basics Assessment
#
# ## Complete the Tasks in bold below. Keep in mind, you may need to run some of these tasks as Python scripts.

# %% [markdown]
# ----------
# #### TASK: Open the *dog_backpack.jpg* image from the DATA folder and display it in the notebook. Make sure to correct for the RGB order.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
img = cv2.imread('../DATA/dog_backpack.jpg') #, cv2.IMREAD_GRAYSCALE)
plt.imshow(img)

# %%
new_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# 가지고 있는 입력 데이터를 convert하는 함수
plt.imshow(new_img)

# %% [markdown]
# #### TASK: Flip the image upside down and display it in the notebook.

# %%
new_img = cv2.flip(new_img, 0)
plt.imshow(new_img)

# %% [markdown]
# #### TASK: Draw an empty RED rectangle around the dogs face and display the image in the notebook.

# %%
new_img = cv2.flip(new_img, 0)
plt.imshow(new_img)

# %%
cv2.rectangle(new_img, pt1 = (250, 400), pt2 = (600, 700), color=(255, 0, 0), thickness=10)
plt.imshow(new_img)

# %% [markdown]
# #### TASK: Draw a BLUE TRIANGLE in the middle of the image. The size and angle is up to you, but it should be a triangle (three sides) in any orientation.

# %%
new_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# 가지고 있는 입력 데이터를 convert하는 함수
plt.imshow(new_img)

# %%
vertices = np.array([[250,700], [((250+600)/2),400], [600,700]], np.int32)
# 폴리곤 이미지를 위한 배열 타입
vertices
# Out:
# array([[250, 700],
#        [425, 400],
#        [600, 700]])

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[250, 700]],
#
#        [[425, 400]],
#
#        [[600, 700]]])

# %%
cv2.polylines(new_img, [pts], isClosed=True, color=(0, 0, 255), thickness=20)
plt.imshow(new_img)

# %% [markdown]
# #  보너스 삼각형 채우는 것

# %%
cv2.fillPoly(new_img, [pts], color=(0, 0, 255))
plt.imshow(new_img)

# %%
new_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# 가지고 있는 입력 데이터를 convert하는 함수
plt.imshow(new_img)

# 엥??

# %% [markdown]
# # task draw an empty red img around the dog face and display the image in the note

# %%
new_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# 가지고 있는 입력 데이터를 convert하는 함수
plt.imshow(new_img)

# %% [markdown]
# #### TASK: (NOTE: YOU WILL NEED TO RUN THIS AS A SCRIPT). Create a script that opens the picture and allows you to draw empty red circles whever you click the RIGHT MOUSE BUTTON DOWN.

# %%
img = cv2.imread('../DATA/dog_backpack.jpg') #, cv2.IMREAD_GRAYSCALE)
# plt.imshow(img)

new_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# 가지고 있는 입력 데이터를 convert하는 함수
# plt.imshow(new_img)

# %%
import cv2
import numpy as np
img = cv2.imread('./DATA/dog_backpack.jpg') #, cv2.IMREAD_GRAYSCALE)
# plt.imshow(img)

new_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# 가지고 있는 입력 데이터를 convert하는 함수
# plt.imshow(new_img)
# python script로 작성해서 실행할 예정이다.
def draw_circle(event, x, y, flags, param):
    if event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(new_img, (x,y), 100, (0,0,255), 5)
    # elif event == cv2.EVENT_RBUTTONDOWN:
        # cv2.circle(img, (x,y), 100, (0,0,255), 5)
        
        
img = new_img
cv2.namedWindow(winname='my_drawing_evnet')
cv2.setMouseCallback('my_drawing_evnet', draw_circle)

while True:
    cv2.imshow('my_drawing_evnet' , img)
    if (cv2.waitKey(1) & 0xFF == 27):
        # esc를 치면 꺼진다.
        break
        
cv2.destroyAllWindows()
